# %%
# !pip install kagglehub
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
import kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (0.3.11)
# Requirement already satisfied: packaging in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from kagglehub) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from requests->kagglehub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from requests->kagglehub) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\yash\appdata\local\programs\python\python312\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
path = kagglehub.dataset_download("himelsarder/road-accident-survival-dataset")
df = pd.read_csv(path + "/accident.csv")
df.shape
df.head()

plt.figure(figsize=(8,5))
sns.barplot(x="Gender", y="Survived", data=df)
plt.title("Bar Plot of Survival Rate by Gender")
plt.show()
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/himelsarder/road-accident-survival-dataset?dataset_version_number=1...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.19k/1.19k [00:00<00:00, 611kB/s]
# Extracting files...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=20, kde=True)
plt.title("Distribution Plot of Age")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="Helmet_Used", y="Speed_of_Impact", hue="Survived", data=df)
plt.title("Box Plot of Speed of Impact vs. Helmet Usage & Survival")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="Seatbelt_Used", hue="Survived", data=df)
plt.title("Count Plot of Survival Rate by Seatbelt Usage")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Speed_of_Impact", y="Age", hue="Survived", data=df)
plt.title("Scatter Plot of Speed of Impact vs Age (Colored by Survival)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
counts = df['Survived'].value_counts()
counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['green','red'])
plt.title('Pie Chart of Survival')
plt.show()
